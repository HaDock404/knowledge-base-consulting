# %%
from firecrawl import FirecrawlApp

app = FirecrawlApp(api_key="fc-4ddc467fadde4fad873d8071fb5e174a")

# Crawl a website:
crawl_status = app.crawl_url(
  'https://www.accteam.fr/', 
  params={
    'limit': 10, 
    'scrapeOptions': {'formats': ['markdown', 'html']}
  }
)
print(crawl_status)
# Out:
# {'success': True, 'status': 'completed', 'completed': 11, 'total': 11, 'creditsUsed': 11, 'expiresAt': '2025-02-20T10:27:00.000Z', 'data': [{'html': '<!DOCTYPE html><html lang="fr" prefix="og: http://ogp.me/ns#">\n\n<body id="page-top">\n    \n    <div class="alert alert-warning alert-dismissible fade show" role="alert" id="bandeau-cookies">\n        <span class="">Ce site utilise des cookies -\n            <a href="https://www.accteam.fr/mentions-legales" class="souligne">En savoir plus</a> -\n            <button class="btn btn-primary btn-cookies" data-dismiss="alert" aria-label="Close">\n                Ok\n            </button>\n        </span>\n    </div>\n\n        <!-- Navigation -->\n    \n    \n        \n    <!-- Header -->\n    \n\n    <!-- Label Finance Innovation -->\n    <section id="services" class="p-5">\n        <div class="container">\n            <div class="row">\n                <div class="col-lg-12 text-center">\n                    <div class="row">\n          
# ...

# %%
crawl_status
# Out:
# {'success': True,
#  'status': 'completed',
#  'completed': 11,
#  'total': 11,
#  'creditsUsed': 11,
#  'expiresAt': '2025-02-20T10:27:00.000Z',
# ...

# %%
import json

with open("fichier.json", "w", encoding="utf-8") as f:
    json.dump({"contenu": crawl_status}, f, ensure_ascii=False, indent=4)
# Out:
# Fichier JSON enregistré avec succès.
